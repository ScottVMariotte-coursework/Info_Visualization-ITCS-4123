# %%
import pandas as pd

df = pd.read_csv("1976-2016-president.csv")

# %%
x = df[["year","state","party","candidatevotes","totalvotes"]]
x
# Out:
#       year    state                       party  candidatevotes  totalvotes
# 0     1976  Alabama                    democrat          659170     1182850
# 1     1976  Alabama                  republican          504070     1182850
# 2     1976  Alabama  american independent party            9198     1182850
# 3     1976  Alabama                 prohibition            6669     1182850
# 4     1976  Alabama         communist party use            1954     1182850
# ...    ...      ...                         ...             ...         ...
# 3735  2016  Wyoming                         NaN            6904      258788
# 3736  2016  Wyoming                 independent            3224      258788
# 3737  2016  Wyoming                         NaN            2661      258788
# 3738  2016  Wyoming          constitution party            2042      258788
# 3739  2016  Wyoming                         NaN             278      258788
#
# [3740 rows x 5 columns]

# %%
df.to_csv('trimedData.csv', index = False)
